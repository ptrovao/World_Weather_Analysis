# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# %%
# Retrieve info from all cities
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval.     ")
print("------------------------------")

# Counters for 50 cities in 10 sets for the 500 total
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_descript = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_descript})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval.
# ------------------------------
# Processing Record 1 of Set 1 | pisco
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | dera din panah
# City not found. Skipping...
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | georgetown
# Processing Record 8 of Set 1 | mayo
# Processing Record 9 of Set 1 | porto velho
# Processing Record 10 of Set 1 | lucea
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | avarua
# Processing Record 14 of Set 1 | xinqing
# Processing Record 15 of Set 1 | waw
# Processing Record 16 of Set 1 | bredasdorp
# Processing Record 17 of Set 1 | victoria
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | tuktoyaktuk
# Processing Record 20 of Set 1 | bluff
# Processing Record 21 of Set 1 | puerto leguizamo
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | chokurdakh
# Processing Record 24 of Set 1 | port alfred
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | busselton
# Processing Record 28 of Set 1 | khatanga
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | kodiak
# Processing Record 31 of Set 1 | ginda
# Processing Record 32 of Set 1 | sorland
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | siuri
# Processing Record 36 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | yarkovo
# Processing Record 38 of Set 1 | forecariah
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | souillac
# Processing Record 44 of Set 1 | tucson
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | upernavik
# Processing Record 48 of Set 1 | jamestown
# Processing Record 49 of Set 1 | marsa matruh
# Processing Record 50 of Set 1 | umm lajj
# Processing Record 1 of Set 2 | cherskiy
# Processing Record 2 of Set 2 | estelle
# Processing Record 3 of Set 2 | qaqortoq
# Processing Record 4 of Set 2 | saint-philippe
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | los llanos de aridane
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | vila velha
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | hermanus
# Processing Record 12 of Set 2 | alcaniz
# Processing Record 13 of Set 2 | katsuura
# Processing Record 14 of Set 2 | port hardy
# Processing Record 15 of Set 2 | boca do acre
# Processing Record 16 of Set 2 | goundam
# Processing Record 17 of Set 2 | beringovskiy
# Processing Record 18 of Set 2 | shimoda
# Processing Record 19 of Set 2 | tautira
# Processing Record 20 of Set 2 | ancud
# Processing Record 21 of Set 2 | sringeri
# Processing Record 22 of Set 2 | bastia
# Processing Record 23 of Set 2 | cabo san lucas
# Processing Record 24 of Set 2 | leningradskiy
# Processing Record 25 of Set 2 | kozmodemyansk
# Processing Record 26 of Set 2 | ahipara
# Processing Record 27 of Set 2 | biak
# Processing Record 28 of Set 2 | mahebourg
# Processing Record 29 of Set 2 | rosario
# Processing Record 30 of Set 2 | southbridge
# Processing Record 31 of Set 2 | hokitika
# Processing Record 32 of Set 2 | ponta do sol
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 2 | havelock
# Processing Record 36 of Set 2 | madimba
# Processing Record 37 of Set 2 | mar del plata
# Processing Record 38 of Set 2 | narsaq
# Processing Record 39 of Set 2 | mouzakion
# City not found. Skipping...
# Processing Record 40 of Set 2 | gandajika
# Processing Record 41 of Set 2 | mehamn
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | kuching
# Processing Record 44 of Set 2 | surab
# Processing Record 45 of Set 2 | airai
# Processing Record 46 of Set 2 | butaritari
# Processing Record 47 of Set 2 | limbang
# Processing Record 48 of Set 2 | puerto carreno
# Processing Record 49 of Set 2 | fivizzano
# Processing Record 50 of Set 2 | ballater
# Processing Record 1 of Set 3 | burica
# City not found. Skipping...
# Processing Record 2 of Set 3 | batagay
# Processing Record 3 of Set 3 | canico
# Processing Record 4 of Set 3 | kemnay
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | flinders
# Processing Record 8 of Set 3 | gondar
# Processing Record 9 of Set 3 | sal rei
# Processing Record 10 of Set 3 | vila franca do campo
# Processing Record 11 of Set 3 | codrington
# Processing Record 12 of Set 3 | wakkanai
# Processing Record 13 of Set 3 | bambous virieux
# Processing Record 14 of Set 3 | santa cruz
# Processing Record 15 of Set 3 | requena
# Processing Record 16 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 17 of Set 3 | morrope
# Processing Record 18 of Set 3 | geraldton
# Processing Record 19 of Set 3 | pyshma
# Processing Record 20 of Set 3 | mala vyska
# Processing Record 21 of Set 3 | reo
# Processing Record 22 of Set 3 | henties bay
# Processing Record 23 of Set 3 | belogorsk
# Processing Record 24 of Set 3 | touros
# Processing Record 25 of Set 3 | severo-yeniseyskiy
# Processing Record 26 of Set 3 | teahupoo
# Processing Record 27 of Set 3 | tiksi
# Processing Record 28 of Set 3 | bure
# Processing Record 29 of Set 3 | ilulissat
# Processing Record 30 of Set 3 | chifeng
# Processing Record 31 of Set 3 | kaitangata
# Processing Record 32 of Set 3 | longlac
# City not found. Skipping...
# Processing Record 33 of Set 3 | lianran
# Processing Record 34 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 3 | altea
# Processing Record 36 of Set 3 | lawton
# Processing Record 37 of Set 3 | lagos
# Processing Record 38 of Set 3 | mumford
# Processing Record 39 of Set 3 | nokaneng
# Processing Record 40 of Set 3 | egvekinot
# Processing Record 41 of Set 3 | aklavik
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | acarau
# Processing Record 44 of Set 3 | agadir
# Processing Record 45 of Set 3 | makung
# City not found. Skipping...
# Processing Record 46 of Set 3 | nantucket
# Processing Record 47 of Set 3 | shingu
# Processing Record 48 of Set 3 | barranca
# Processing Record 49 of Set 3 | tasiilaq
# Processing Record 50 of Set 3 | kutum
# Processing Record 1 of Set 4 | taltal
# Processing Record 2 of Set 4 | hami
# Processing Record 3 of Set 4 | east london
# Processing Record 4 of Set 4 | pevek
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | lebu
# Processing Record 9 of Set 4 | buchanan
# Processing Record 10 of Set 4 | grand gaube
# Processing Record 11 of Set 4 | canyon lake
# Processing Record 12 of Set 4 | melukote
# Processing Record 13 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 4 | havoysund
# Processing Record 15 of Set 4 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 4 | avera
# Processing Record 17 of Set 4 | timra
# Processing Record 18 of Set 4 | kudahuvadhoo
# Processing Record 19 of Set 4 | feijo
# Processing Record 20 of Set 4 | kaeo
# Processing Record 21 of Set 4 | fortuna
# Processing Record 22 of Set 4 | kletnya
# Processing Record 23 of Set 4 | bubaque
# Processing Record 24 of Set 4 | necochea
# Processing Record 25 of Set 4 | tshikapa
# Processing Record 26 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 4 | pandan
# Processing Record 29 of Set 4 | abhar
# Processing Record 30 of Set 4 | barrow
# Processing Record 31 of Set 4 | nurobod
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | epe
# Processing Record 34 of Set 4 | islampur
# Processing Record 35 of Set 4 | vardo
# Processing Record 36 of Set 4 | ghanzi
# Processing Record 37 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 38 of Set 4 | hobart
# Processing Record 39 of Set 4 | clyde river
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | osakarovka
# Processing Record 42 of Set 4 | sistranda
# Processing Record 43 of Set 4 | grindavik
# Processing Record 44 of Set 4 | san patricio
# Processing Record 45 of Set 4 | cockburn town
# Processing Record 46 of Set 4 | mayumba
# Processing Record 47 of Set 4 | natal
# Processing Record 48 of Set 4 | tecoanapa
# Processing Record 49 of Set 4 | sisimiut
# Processing Record 50 of Set 4 | longyearbyen
# Processing Record 1 of Set 5 | novy bydzov
# Processing Record 2 of Set 5 | togur
# Processing Record 3 of Set 5 | ketchikan
# Processing Record 4 of Set 5 | milkovo
# Processing Record 5 of Set 5 | qaanaaq
# Processing Record 6 of Set 5 | sao joao da barra
# Processing Record 7 of Set 5 | bonavista
# Processing Record 8 of Set 5 | lavrentiya
# Processing Record 9 of Set 5 | yellowknife
# Processing Record 10 of Set 5 | illapel
# Processing Record 11 of Set 5 | fuyang
# Processing Record 12 of Set 5 | koygorodok
# Processing Record 13 of Set 5 | bethel
# Processing Record 14 of Set 5 | ayolas
# Processing Record 15 of Set 5 | rypin
# Processing Record 16 of Set 5 | port-gentil
# Processing Record 17 of Set 5 | ambon
# Processing Record 18 of Set 5 | sao gabriel da cachoeira
# Processing Record 19 of Set 5 | vanavara
# Processing Record 20 of Set 5 | saskylakh
# Processing Record 21 of Set 5 | urumqi
# Processing Record 22 of Set 5 | luderitz
# Processing Record 23 of Set 5 | cayenne
# Processing Record 24 of Set 5 | bafoulabe
# Processing Record 25 of Set 5 | paraiba do sul
# Processing Record 26 of Set 5 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 5 | shache
# Processing Record 28 of Set 5 | ciudad bolivar
# Processing Record 29 of Set 5 | hasaki
# Processing Record 30 of Set 5 | adrar
# Processing Record 31 of Set 5 | zhanaozen
# Processing Record 32 of Set 5 | kenai
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | chiredzi
# Processing Record 35 of Set 5 | sitka
# Processing Record 36 of Set 5 | acapulco
# Processing Record 37 of Set 5 | santander
# Processing Record 38 of Set 5 | chuy
# Processing Record 39 of Set 5 | yialos
# City not found. Skipping...
# Processing Record 40 of Set 5 | traunstein
# Processing Record 41 of Set 5 | whitehorse
# Processing Record 42 of Set 5 | bangui
# Processing Record 43 of Set 5 | faanui
# Processing Record 44 of Set 5 | muros
# Processing Record 45 of Set 5 | mpanda
# Processing Record 46 of Set 5 | iralaya
# Processing Record 47 of Set 5 | korcula
# Processing Record 48 of Set 5 | isangel
# Processing Record 49 of Set 5 | makushino
# Processing Record 50 of Set 5 | hualmay
# Processing Record 1 of Set 6 | vao
# Processing Record 2 of Set 6 | bomet
# Processing Record 3 of Set 6 | udachnyy
# Processing Record 4 of Set 6 | bitung
# Processing Record 5 of Set 6 | kayes
# Processing Record 6 of Set 6 | roma
# Processing Record 7 of Set 6 | erdenet
# Processing Record 8 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 6 | gravdal
# Processing Record 10 of Set 6 | kirillov
# Processing Record 11 of Set 6 | faya
# Processing Record 12 of Set 6 | gatton
# Processing Record 13 of Set 6 | ugoofaaru
# Processing Record 14 of Set 6 | gonzalez
# Processing Record 15 of Set 6 | energetik
# Processing Record 16 of Set 6 | merritt
# Processing Record 17 of Set 6 | sao mateus
# Processing Record 18 of Set 6 | kangaatsiaq
# Processing Record 19 of Set 6 | poros
# Processing Record 20 of Set 6 | chiria
# Processing Record 21 of Set 6 | talcahuano
# Processing Record 22 of Set 6 | presidencia roque saenz pena
# Processing Record 23 of Set 6 | portland
# Processing Record 24 of Set 6 | margate
# Processing Record 25 of Set 6 | riyadh
# Processing Record 26 of Set 6 | beoumi
# Processing Record 27 of Set 6 | auki
# Processing Record 28 of Set 6 | klaksvik
# Processing Record 29 of Set 6 | yulara
# Processing Record 30 of Set 6 | punta umbria
# Processing Record 31 of Set 6 | san juan bautista
# Processing Record 32 of Set 6 | aksarayskiy
# Processing Record 33 of Set 6 | omsukchan
# Processing Record 34 of Set 6 | videle
# Processing Record 35 of Set 6 | kuna
# Processing Record 36 of Set 6 | daru
# Processing Record 37 of Set 6 | carutapera
# Processing Record 38 of Set 6 | honningsvag
# Processing Record 39 of Set 6 | nome
# Processing Record 40 of Set 6 | kununurra
# Processing Record 41 of Set 6 | bourail
# Processing Record 42 of Set 6 | guerrero negro
# Processing Record 43 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 44 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 45 of Set 6 | talnakh
# Processing Record 46 of Set 6 | oranjemund
# Processing Record 47 of Set 6 | tommot
# Processing Record 48 of Set 6 | taunggyi
# Processing Record 49 of Set 6 | ekhabi
# Processing Record 50 of Set 6 | oktyabrskoye
# Processing Record 1 of Set 7 | burnie
# Processing Record 2 of Set 7 | makakilo city
# Processing Record 3 of Set 7 | biloela
# Processing Record 4 of Set 7 | sao jose da coroa grande
# Processing Record 5 of Set 7 | uyuni
# Processing Record 6 of Set 7 | provideniya
# Processing Record 7 of Set 7 | benguela
# Processing Record 8 of Set 7 | sao filipe
# Processing Record 9 of Set 7 | dongning
# Processing Record 10 of Set 7 | talara
# Processing Record 11 of Set 7 | kandrian
# Processing Record 12 of Set 7 | toyoshina
# Processing Record 13 of Set 7 | agdam
# Processing Record 14 of Set 7 | san marcos
# Processing Record 15 of Set 7 | kruisfontein
# Processing Record 16 of Set 7 | galiwinku
# City not found. Skipping...
# Processing Record 17 of Set 7 | taoudenni
# Processing Record 18 of Set 7 | timmins
# Processing Record 19 of Set 7 | mogadishu
# Processing Record 20 of Set 7 | bowen
# Processing Record 21 of Set 7 | tarbert
# Processing Record 22 of Set 7 | esfarayen
# Processing Record 23 of Set 7 | fort morgan
# Processing Record 24 of Set 7 | bontang
# Processing Record 25 of Set 7 | tarime
# Processing Record 26 of Set 7 | arsikere
# Processing Record 27 of Set 7 | bathsheba
# Processing Record 28 of Set 7 | vallenar
# Processing Record 29 of Set 7 | zhezkazgan
# Processing Record 30 of Set 7 | hurbanovo
# Processing Record 31 of Set 7 | banff
# Processing Record 32 of Set 7 | brae
# Processing Record 33 of Set 7 | cam ranh
# Processing Record 34 of Set 7 | coihaique
# Processing Record 35 of Set 7 | mongoumba
# Processing Record 36 of Set 7 | laguna
# Processing Record 37 of Set 7 | usinsk
# Processing Record 38 of Set 7 | prainha
# Processing Record 39 of Set 7 | betare oya
# Processing Record 40 of Set 7 | norman wells
# Processing Record 41 of Set 7 | iwanai
# Processing Record 42 of Set 7 | yar-sale
# Processing Record 43 of Set 7 | salalah
# Processing Record 44 of Set 7 | borogontsy
# Processing Record 45 of Set 7 | poum
# Processing Record 46 of Set 7 | qandala
# Processing Record 47 of Set 7 | baiyin
# Processing Record 48 of Set 7 | nanaimo
# Processing Record 49 of Set 7 | saint george
# Processing Record 50 of Set 7 | idrinskoye
# Processing Record 1 of Set 8 | qasigiannguit
# Processing Record 2 of Set 8 | manjacaze
# Processing Record 3 of Set 8 | muli
# Processing Record 4 of Set 8 | carupano
# Processing Record 5 of Set 8 | khani
# Processing Record 6 of Set 8 | maniitsoq
# Processing Record 7 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 8 | utinga
# Processing Record 9 of Set 8 | nisia floresta
# Processing Record 10 of Set 8 | ingham
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | anloga
# Processing Record 13 of Set 8 | sibolga
# Processing Record 14 of Set 8 | umm kaddadah
# Processing Record 15 of Set 8 | carballo
# Processing Record 16 of Set 8 | saint-joseph
# Processing Record 17 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 18 of Set 8 | alice springs
# Processing Record 19 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 20 of Set 8 | bolshoy log
# City not found. Skipping...
# Processing Record 21 of Set 8 | plettenberg bay
# Processing Record 22 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 23 of Set 8 | lakota
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | sulangan
# Processing Record 26 of Set 8 | delta del tigre
# Processing Record 27 of Set 8 | aasiaat
# Processing Record 28 of Set 8 | belyy yar
# Processing Record 29 of Set 8 | ortakoy
# Processing Record 30 of Set 8 | nanortalik
# Processing Record 31 of Set 8 | san borja
# Processing Record 32 of Set 8 | nandurbar
# Processing Record 33 of Set 8 | ghatanji
# Processing Record 34 of Set 8 | aripuana
# Processing Record 35 of Set 8 | dusti
# Processing Record 36 of Set 8 | banmo
# City not found. Skipping...
# Processing Record 37 of Set 8 | celestun
# Processing Record 38 of Set 8 | coquimbo
# Processing Record 39 of Set 8 | kupang
# Processing Record 40 of Set 8 | trinidad
# Processing Record 41 of Set 8 | kahului
# Processing Record 42 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 8 | graaff-reinet
# Processing Record 44 of Set 8 | inuvik
# Processing Record 45 of Set 8 | abu zabad
# Processing Record 46 of Set 8 | sahrak
# City not found. Skipping...
# Processing Record 47 of Set 8 | tabou
# Processing Record 48 of Set 8 | atchison
# Processing Record 49 of Set 8 | leh
# Processing Record 50 of Set 8 | jinxiang
# Processing Record 1 of Set 9 | fairbanks
# Processing Record 2 of Set 9 | tengzhou
# Processing Record 3 of Set 9 | miles city
# Processing Record 4 of Set 9 | imeni poliny osipenko
# Processing Record 5 of Set 9 | sur
# Processing Record 6 of Set 9 | itoman
# Processing Record 7 of Set 9 | esperance
# Processing Record 8 of Set 9 | kieta
# Processing Record 9 of Set 9 | atar
# Processing Record 10 of Set 9 | pochutla
# Processing Record 11 of Set 9 | srednekolymsk
# Processing Record 12 of Set 9 | kavarna
# Processing Record 13 of Set 9 | hobyo
# Processing Record 14 of Set 9 | noshiro
# Processing Record 15 of Set 9 | rostusa
# Processing Record 16 of Set 9 | narasannapeta
# Processing Record 17 of Set 9 | kisanga
# Processing Record 18 of Set 9 | jishou
# Processing Record 19 of Set 9 | awjilah
# Processing Record 20 of Set 9 | mahajanga
# Processing Record 21 of Set 9 | palencia
# Processing Record 22 of Set 9 | aykhal
# Processing Record 23 of Set 9 | port keats
# Processing Record 24 of Set 9 | constantine
# Processing Record 25 of Set 9 | aporawan
# City not found. Skipping...
# Processing Record 26 of Set 9 | port hedland
# Processing Record 27 of Set 9 | kajaani
# Processing Record 28 of Set 9 | cidreira
# Processing Record 29 of Set 9 | merauke
# Processing Record 30 of Set 9 | clinton
# Processing Record 31 of Set 9 | asosa
# Processing Record 32 of Set 9 | annau
# Processing Record 33 of Set 9 | gao
# Processing Record 34 of Set 9 | praia da vitoria
# Processing Record 35 of Set 9 | bryant
# Processing Record 36 of Set 9 | saint-francois
# Processing Record 37 of Set 9 | vanimo
# Processing Record 38 of Set 9 | noyabrsk
# Processing Record 39 of Set 9 | oruro
# Processing Record 40 of Set 9 | tsumeb
# Processing Record 41 of Set 9 | binga
# Processing Record 42 of Set 9 | suoyarvi
# Processing Record 43 of Set 9 | anchorage
# Processing Record 44 of Set 9 | floriano
# Processing Record 45 of Set 9 | arman
# Processing Record 46 of Set 9 | luanda
# Processing Record 47 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 48 of Set 9 | tura
# Processing Record 49 of Set 9 | dakar
# Processing Record 50 of Set 9 | kontagora
# Processing Record 1 of Set 10 | ereymentau
# Processing Record 2 of Set 10 | domoni
# Processing Record 3 of Set 10 | gourdon
# Processing Record 4 of Set 10 | cabedelo
# Processing Record 5 of Set 10 | severo-kurilsk
# Processing Record 6 of Set 10 | pangnirtung
# Processing Record 7 of Set 10 | tingrela
# City not found. Skipping...
# Processing Record 8 of Set 10 | gamba
# Processing Record 9 of Set 10 | koumac
# Processing Record 10 of Set 10 | khandyga
# Processing Record 11 of Set 10 | chapais
# Processing Record 12 of Set 10 | superior
# Processing Record 13 of Set 10 | caravelas
# Processing Record 14 of Set 10 | balakhninskiy
# Processing Record 15 of Set 10 | villacarrillo
# Processing Record 16 of Set 10 | umea
# Processing Record 17 of Set 10 | pandamatenga
# Processing Record 18 of Set 10 | bambanglipuro
# Processing Record 19 of Set 10 | port lincoln
# Processing Record 20 of Set 10 | pandrup
# Processing Record 21 of Set 10 | padang
# Processing Record 22 of Set 10 | indramayu
# Processing Record 23 of Set 10 | west bay
# Processing Record 24 of Set 10 | miranorte
# City not found. Skipping...
# Processing Record 25 of Set 10 | iqaluit
# Processing Record 26 of Set 10 | tahta
# Processing Record 27 of Set 10 | mercedes
# Processing Record 28 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 10 | visby
# Processing Record 30 of Set 10 | corinto
# Processing Record 31 of Set 10 | koroni
# Processing Record 32 of Set 10 | port blair
# Processing Record 33 of Set 10 | saint albans
# Processing Record 34 of Set 10 | saint-georges
# Processing Record 35 of Set 10 | dehloran
# Processing Record 36 of Set 10 | mount isa
# Processing Record 37 of Set 10 | constitucion
# Processing Record 38 of Set 10 | nishihara
# Processing Record 39 of Set 10 | stawell
# Processing Record 40 of Set 10 | mikhaylovka
# Processing Record 41 of Set 10 | san-pedro
# Processing Record 42 of Set 10 | jalu
# Processing Record 43 of Set 10 | elektrenai
# Processing Record 44 of Set 10 | lillooet
# Processing Record 45 of Set 10 | maceio
# Processing Record 46 of Set 10 | esso
# Processing Record 47 of Set 10 | waingapu
# Processing Record 48 of Set 10 | baruun-urt
# Processing Record 49 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 50 of Set 10 | gohad
# Processing Record 1 of Set 11 | emborion
# Processing Record 2 of Set 11 | cauquenes
# Processing Record 3 of Set 11 | fukue
# Processing Record 4 of Set 11 | yeppoon
# Processing Record 5 of Set 11 | kirakira
# Processing Record 6 of Set 11 | nuevitas
# Processing Record 7 of Set 11 | haines junction
# Processing Record 8 of Set 11 | tiarei
# Processing Record 9 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 11 | tampilisan
# Processing Record 12 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 13 of Set 11 | moyale
# Processing Record 14 of Set 11 | namibe
# Processing Record 15 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 11 | kavieng
# Processing Record 17 of Set 11 | mattru
# Processing Record 18 of Set 11 | santa marta
# Processing Record 19 of Set 11 | ukiah
# Processing Record 20 of Set 11 | behshahr
# Processing Record 21 of Set 11 | cuamba
# Processing Record 22 of Set 11 | issoire
# Processing Record 23 of Set 11 | krasnoselkup
# Processing Record 24 of Set 11 | laela
# Processing Record 25 of Set 11 | scarborough
# Processing Record 26 of Set 11 | vung tau
# Processing Record 27 of Set 11 | znamenskoye
# Processing Record 28 of Set 11 | berlevag
# Processing Record 29 of Set 11 | paraiso
# Processing Record 30 of Set 11 | thinadhoo
# Processing Record 31 of Set 11 | lorengau
# Processing Record 32 of Set 11 | maralal
# Processing Record 33 of Set 11 | antalaha
# Processing Record 34 of Set 11 | kishni
# Processing Record 35 of Set 11 | marzuq
# Processing Record 36 of Set 11 | dingle
# Processing Record 37 of Set 11 | ostrovnoy
# Processing Record 38 of Set 11 | malindi
# Processing Record 39 of Set 11 | taylors
# Processing Record 40 of Set 11 | izumo
# Processing Record 41 of Set 11 | melilla
# Processing Record 42 of Set 11 | kuandian
# Processing Record 43 of Set 11 | tuatapere
# Processing Record 44 of Set 11 | haian
# Processing Record 45 of Set 11 | veraval
# Processing Record 46 of Set 11 | slave lake
# Processing Record 47 of Set 11 | kuryk
# Processing Record 48 of Set 11 | zaria
# Processing Record 49 of Set 11 | de aar
# Processing Record 50 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 1 of Set 12 | menzelinsk
# Processing Record 2 of Set 12 | sembe
# Processing Record 3 of Set 12 | tamuin
# Processing Record 4 of Set 12 | jacqueville
# Processing Record 5 of Set 12 | mount gambier
# Processing Record 6 of Set 12 | uige
# Processing Record 7 of Set 12 | sinnamary
# Processing Record 8 of Set 12 | alpena
# Processing Record 9 of Set 12 | mbanza-ngungu
# Processing Record 10 of Set 12 | alofi
# Processing Record 11 of Set 12 | komsomolets
# Processing Record 12 of Set 12 | araouane
# Processing Record 13 of Set 12 | liverpool
# Processing Record 14 of Set 12 | camacha
# Processing Record 15 of Set 12 | kimbe
# Processing Record 16 of Set 12 | svetlyy
# Processing Record 17 of Set 12 | asau
# Processing Record 18 of Set 12 | hay river
# Processing Record 19 of Set 12 | luau
# Processing Record 20 of Set 12 | vestmannaeyjar
# Processing Record 21 of Set 12 | grand-santi
# Processing Record 22 of Set 12 | huangmei
# Processing Record 23 of Set 12 | neulengbach
# Processing Record 24 of Set 12 | barcelona
# Processing Record 25 of Set 12 | partenit
# Processing Record 26 of Set 12 | loandjili
# Processing Record 27 of Set 12 | mariental
# Processing Record 28 of Set 12 | xining
# Processing Record 29 of Set 12 | kaduqli
# Processing Record 30 of Set 12 | vaasa
# Processing Record 31 of Set 12 | aviles
# Processing Record 32 of Set 12 | fort worth
# Processing Record 33 of Set 12 | luganville
# Processing Record 34 of Set 12 | maputo
# Processing Record 35 of Set 12 | hofn
# Processing Record 36 of Set 12 | beloha
# Processing Record 37 of Set 12 | pulivendla
# Processing Record 38 of Set 12 | marawi
# Processing Record 39 of Set 12 | olinda
# Processing Record 40 of Set 12 | tunceli
# Processing Record 41 of Set 12 | ahuimanu
# Processing Record 42 of Set 12 | kinsale
# Processing Record 43 of Set 12 | bam
# Processing Record 44 of Set 12 | paita
# Processing Record 45 of Set 12 | inhambane
# Processing Record 46 of Set 12 | shitanjing
# Processing Record 47 of Set 12 | quincy
# Processing Record 48 of Set 12 | muhos
# Processing Record 49 of Set 12 | north bend
# Processing Record 50 of Set 12 | varhaug
# Processing Record 1 of Set 13 | tarhunah
# City not found. Skipping...
# Processing Record 2 of Set 13 | weymouth
# Processing Record 3 of Set 13 | sechura
# Processing Record 4 of Set 13 | walvis bay
# Processing Record 5 of Set 13 | calvinia
# Processing Record 6 of Set 13 | okhotsk
# Processing Record 7 of Set 13 | acopiara
# Processing Record 8 of Set 13 | halifax
# Processing Record 9 of Set 13 | tiruchchendur
# Processing Record 10 of Set 13 | katobu
# Processing Record 11 of Set 13 | te anau
# Processing Record 12 of Set 13 | winnemucca
# Processing Record 13 of Set 13 | saint-pierre
# Processing Record 14 of Set 13 | schneeberg
# Processing Record 15 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 13 | san ramon
# Processing Record 17 of Set 13 | mlonggo
# Processing Record 18 of Set 13 | krasnoshchekovo
# Processing Record 19 of Set 13 | saint-maximin-la-sainte-baume
# Processing Record 20 of Set 13 | khotyn
# Processing Record 21 of Set 13 | seoul
# Processing Record 22 of Set 13 | price
# Processing Record 23 of Set 13 | chernyshevskiy
# Processing Record 24 of Set 13 | ouro preto do oeste
# Processing Record 25 of Set 13 | jumla
# Processing Record 26 of Set 13 | dzilam gonzalez
# Processing Record 27 of Set 13 | eureka
# Processing Record 28 of Set 13 | yeehaw junction
# City not found. Skipping...
# Processing Record 29 of Set 13 | neuquen
# Processing Record 30 of Set 13 | show low
# Processing Record 31 of Set 13 | castro marim
# Processing Record 32 of Set 13 | venice
# Processing Record 33 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 13 | athabasca
# Processing Record 35 of Set 13 | vila
# Processing Record 36 of Set 13 | atambua
# Processing Record 37 of Set 13 | tobetsu
# Processing Record 38 of Set 13 | kikerino
# Processing Record 39 of Set 13 | sajanan
# Processing Record 40 of Set 13 | nouadhibou
# Processing Record 41 of Set 13 | la peca
# Processing Record 42 of Set 13 | takoradi
# Processing Record 43 of Set 13 | nelson bay
# Processing Record 44 of Set 13 | progress
# Processing Record 45 of Set 13 | shangrao
# Processing Record 46 of Set 13 | mahina
# Processing Record 47 of Set 13 | hambantota
# Processing Record 48 of Set 13 | westport
# Processing Record 49 of Set 13 | camalu
# Processing Record 50 of Set 13 | vostok
# Processing Record 1 of Set 14 | lasa
# Processing Record 2 of Set 14 | shubarshi
# Processing Record 3 of Set 14 | choma
# Processing Record 4 of Set 14 | redmond
# Processing Record 5 of Set 14 | college
# Processing Record 6 of Set 14 | seydisehir
# Processing Record 7 of Set 14 | stranda
# Processing Record 8 of Set 14 | lazarev
# Processing Record 9 of Set 14 | voi
# Processing Record 10 of Set 14 | san angelo
# Processing Record 11 of Set 14 | pyaozerskiy
# Processing Record 12 of Set 14 | pacific grove
# Processing Record 13 of Set 14 | stromness
# Processing Record 14 of Set 14 | lagoa
# Processing Record 15 of Set 14 | kinloss
# Processing Record 16 of Set 14 | torata
# Processing Record 17 of Set 14 | machiques
# Processing Record 18 of Set 14 | maumere
# Processing Record 19 of Set 14 | karoi
# Processing Record 20 of Set 14 | lata
# Processing Record 21 of Set 14 | pedasi
# Processing Record 22 of Set 14 | samarai
# Processing Record 23 of Set 14 | horodyshche
# Processing Record 24 of Set 14 | denpasar
# Processing Record 25 of Set 14 | bosaso
# Processing Record 26 of Set 14 | boende
# Processing Record 27 of Set 14 | labytnangi
# Processing Record 28 of Set 14 | vieques
# Processing Record 29 of Set 14 | huarmey
# Processing Record 30 of Set 14 | witu
# Processing Record 31 of Set 14 | sorong
# Processing Record 32 of Set 14 | bandarbeyla
# Processing Record 33 of Set 14 | cockburn harbour
# City not found. Skipping...
# Processing Record 34 of Set 14 | aioi
# Processing Record 35 of Set 14 | barabai
# Processing Record 36 of Set 14 | petrolina
# Processing Record 37 of Set 14 | garoua
# Processing Record 38 of Set 14 | axim
# Processing Record 39 of Set 14 | tokat
# Processing Record 40 of Set 14 | jinchang
# Processing Record 41 of Set 14 | alyangula
# Processing Record 42 of Set 14 | sao felipe
# Processing Record 43 of Set 14 | sinop
# Processing Record 44 of Set 14 | churapcha
# Processing Record 45 of Set 14 | bhola
# Processing Record 46 of Set 14 | tual
# Processing Record 47 of Set 14 | la paz centro
# Processing Record 48 of Set 14 | mitsamiouli
# Processing Record 49 of Set 14 | oconomowoc
# Processing Record 50 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 1 of Set 15 | rio grande
# Processing Record 2 of Set 15 | riyaq
# City not found. Skipping...
# Processing Record 3 of Set 15 | abu dhabi
# Processing Record 4 of Set 15 | freetown
# Processing Record 5 of Set 15 | sola
# Processing Record 6 of Set 15 | ariquemes
# Processing Record 7 of Set 15 | monze
# Processing Record 8 of Set 15 | shenkursk
# Processing Record 9 of Set 15 | katherine
# Processing Record 10 of Set 15 | matara
# Processing Record 11 of Set 15 | buala
# Processing Record 12 of Set 15 | bolonchen
# City not found. Skipping...
# Processing Record 13 of Set 15 | fairfield
# Processing Record 14 of Set 15 | magistralnyy
# Processing Record 15 of Set 15 | yumen
# Processing Record 16 of Set 15 | nizwa
# Processing Record 17 of Set 15 | papara
# Processing Record 18 of Set 15 | nysa
# Processing Record 19 of Set 15 | bethlehem
# Processing Record 20 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 21 of Set 15 | husavik
# Processing Record 22 of Set 15 | damietta
# Processing Record 23 of Set 15 | pacifica
# Processing Record 24 of Set 15 | puerto del rosario
# Processing Record 25 of Set 15 | najran
# Processing Record 26 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 27 of Set 15 | ishigaki
# Processing Record 28 of Set 15 | newport beach
# Processing Record 29 of Set 15 | ilhabela
# Processing Record 30 of Set 15 | nola
# Processing Record 31 of Set 15 | rostaq
# City not found. Skipping...
# Processing Record 32 of Set 15 | gat
# Processing Record 33 of Set 15 | ola
# Processing Record 34 of Set 15 | neiafu
# Processing Record 35 of Set 15 | amapa
# Processing Record 36 of Set 15 | broome
# Processing Record 37 of Set 15 | takaka
# Processing Record 38 of Set 15 | shuangcheng
# Processing Record 39 of Set 15 | grand island
# Processing Record 40 of Set 15 | joensuu
# Processing Record 41 of Set 15 | maxixe
# Processing Record 42 of Set 15 | yenagoa
# Processing Record 43 of Set 15 | lubaczow
# Processing Record 44 of Set 15 | kracheh
# City not found. Skipping...
# Processing Record 45 of Set 15 | miranda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 689

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Pisco      PE -13.7000  -76.2167     21.03        78          75
# 1          Hilo      US  19.7297 -155.0900     23.85        91          90
# 2    Nikolskoye      RU  59.7035   30.7861    -17.56        98           8
# 3         Vaini      TO -21.2000 -175.2000     27.09        89          75
# 4        Atuona      PF  -9.8000 -139.0333     25.83        75           5
# 5    Georgetown      MY   5.4112  100.3354     25.50        77          20
# 6          Mayo      US  38.8876  -76.5119     10.77        59          75
# 7   Porto Velho      BR  -8.7619  -63.9039     28.03        78          20
# 8         Lucea      JM  18.4510  -78.1736     27.92        76          90
# 9  Punta Arenas      CL -53.1500  -70.9167     13.06        41          20
#
#    Wind Speed           Description
# 0        7.20         broken clouds
# 1        5.66  heavy intensity rain
# 2        2.14             clear sky
# 3        6.17         broken clouds
# 4        8.18             clear sky
# 5        4.63            few clouds
# 6        0.00         broken clouds
# 7        1.03            few clouds
# 8        3.10       overcast clouds
# 9        9.26            few clouds

# %%
# Export data frame as CSV
output_data_file = 'Weather_Database/Cities.csv'
city_data_df.to_csv(output_data_file,index_label='City_ID')
